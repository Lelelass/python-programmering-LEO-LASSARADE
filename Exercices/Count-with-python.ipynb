# %%
import math
a, b = 3, 4
c = math.sqrt(a ** 2 + b ** 2)
print("1a : " + str(c))
# Out:
# 1a : 5.0

# %%
c2, a2 = 7, 5
b2 = round(math.sqrt(c2 ** 2 - a2 ** 2), 2)
print("1b : " + str(b2))
# Out:
# 1b : 4.9
